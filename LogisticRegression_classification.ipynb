# %% [markdown]
# <a href="https://colab.research.google.com/github/kishore-yalamaddi/ml_practice/blob/main/LogisticRegression_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.xlabel("age")
plt.ylabel("bought_insurance")
plt.scatter(df.age,df.bought_insurance,color='red',marker="+")

# %%
x = df.drop("bought_insurance",axis="columns")
x.head()
# Out:
#    age
# 0   22
# 1   25
# 2   47
# 3   52
# 4   46

# %%
y = df.bought_insurance
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: bought_insurance, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#     age
# 13   29
# 1    25
# 0    22
# 11   28
# 15   55

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 4    46
# 26   23
# 7    60
# 18   19
# 10   18
# 19   18
# 8    62
# 14   49
# 12   27

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 1, 0])

# %%
y_test
# Out:
# 4     1
# 26    0
# 7     1
# 18    0
# 10    0
# 19    0
# 8     1
# 14    1
# 12    0
# Name: bought_insurance, dtype: int64

# %%
lr.score(x_test, y_test)
# Out:
# 1.0
